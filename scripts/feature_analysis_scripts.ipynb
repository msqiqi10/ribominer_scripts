# %%
abs_path = "/home/zzz0054/bio/7-5"
out_dir_path = "FeatureAnalysis"

# %%
# !RiboDensityForSpecificRegion -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/ -U codon -M RPKM -L 1 -R 100
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# There are 6600 transcripts with both start and stop codon will be used for following analysis.

# %%
# !RiboDensityAtEachKindAAOrCodon -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/RiboDensityAtEachKindAAOrCodon -M RPKM -S {abs_path}/selected.transcripts.info.txt -l 100 -n 10 --table 1 -F {abs_path}/ProteinCodingSeq_cds_sequences.fa
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# There are 6600 transcripts from /home/zzz0054/bio/7-5/selected.transcripts.info.txt used for following analysis.
# The number of transcripts filtered by filter1 (len(CDS_seq)%3!=0) is : 0
# The number of transcripts filtered by filter2 (len(CDS_seq)<inCDS_lengthFilterParma) is :47
# The number of transcripts filtered by filter3 (cds_reads < inCDS_countsFilterParma) is : 2733
# The number of transcripts used for following analysis is: 3820
# The number of transcripts filtered by filter1 (len(CDS_seq)%3!=0) is : 0
# The number of transcripts filtered by filter2 (len(CDS_seq)<inCDS_lengthFilterParma) is :47
# The number of transcripts filtered by filter3 (cds_reads < inCDS_countsFilterParma) is : 2739
# The number of transcripts used for following analysis is: 3814
# The number of transcripts filtered by filter1 (len(CDS_seq)%3!=0) is : 0
# ...

# %%
# !cut -f2- /home/zzz0054/bio/7-5/all.transcripts.info.txt > /home/zzz0054/bio/7-5/selected.transcripts.info.txt

# %%
# !PlotRiboDensityAtEachKindAAOrCodon -i {abs_path}/{out_dir_path}/RiboDensityAtEachKindAAOrCodon_all_codon_density.txt -o {abs_path}/{out_dir_path}/PlotRiboDensityAtEachKindAAOrCodon -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 --level AA
# Out:
# Start the step of plotting...
# /home/zzz0054/miniconda3/envs/ribo4/lib/python3.8/site-packages/RiboMiner/PlotRiboDensityAtEachKindAAOrCodon.py:199: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=np.arange(len(AAs)),y=data_sorted.loc[:,r],palette='husl',ax=ax,alpha=0.9)
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# /home/zzz0054/miniconda3/envs/ribo4/lib/python3.8/site-packages/RiboMiner/PlotRiboDensityAtEachKindAAOrCodon.py:199: FutureWarning:
#
# ...

# %%
# !PlotRiboDensityAtEachKindAAOrCodon -i {abs_path}/{out_dir_path}/RiboDensityAtEachKindAAOrCodon_all_codon_density.txt -o {abs_path}/{out_dir_path}/PlotRiboDensityAtEachKindAAOrCodon_condo -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 --level codon
# Out:
# Start the step of plotting...
# /home/zzz0054/miniconda3/envs/ribo4/lib/python3.8/site-packages/RiboMiner/PlotRiboDensityAtEachKindAAOrCodon.py:116: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=np.arange(len(codons_sort)),y=data_sorted.loc[:,r],palette='husl',ax=ax)
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
## ribosome density at each tri-AA motif
# !RiboDensityAroundTripleteAAMotifs -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/RiboDensityAroundTripleteAAMotifs -M RPKM -S {abs_path}/selected.transcripts.info.txt -F {abs_path}/ProteinCodingSeq_cds_sequences.fa --type2 PPP --type1 PP -l 100 -n 10 --table 1 
## plot
# !PlotRiboDensityAroundTriAAMotifs -i {abs_path}/{out_dir_path}/RiboDensityAroundTripleteAAMotifs_motifDensity_dataframe.txt -o {abs_path}/{out_dir_path}/RiboDensityAroundTripleteAAMotifs -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 --mode mean --ymax 0.2
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# There are 6600 transcripts from /home/zzz0054/bio/7-5/selected.transcripts.info.txt used for following analysis.
# Start analyze the sample: /home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bam
# The number of genes whose length of CDS could not divided by three: 0
# The number of genes whose length of CDS is less than the criteria: 43
# The number of genes whose read counts on CDS are less than the criteria: 2775
# The number of genes whose total read counts after normalization are equal to zero: 22
# The final number of genes used for following analysis is: 3803
# There are 3881 positions used for plot PP
# There are 551 positions used for plot PPP
# This will return motifDensity_1 and motifDensity_2
# Finish the step of calculate the motif density of genes
# Start analyze the sample: /home/zzz0054/bio/7-5/star_out/5008135/Aligned.toTranscriptome.out.sorted.bam
# ...

# %%
## ribosome density at each tri-AA motif
# !RiboDensityAroundTripleteAAMotifs -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/RiboDensityAroundTripleteAAMotifs_D -M RPKM -S {abs_path}/selected.transcripts.info.txt -F {abs_path}/ProteinCodingSeq_cds_sequences.fa --type2 DDD --type1 DD -l 100 -n 10 --table 1
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# There are 6600 transcripts from /home/zzz0054/bio/7-5/selected.transcripts.info.txt used for following analysis.
# Start analyze the sample: /home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bam
# The number of genes whose length of CDS could not divided by three: 0
# The number of genes whose length of CDS is less than the criteria: 43
# The number of genes whose read counts on CDS are less than the criteria: 2775
# The number of genes whose total read counts after normalization are equal to zero: 22
# The final number of genes used for following analysis is: 3803
# There are 7970 positions used for plot DD
# There are 1227 positions used for plot DDD
# This will return motifDensity_1 and motifDensity_2
# Finish the step of calculate the motif density of genes
# Start analyze the sample: /home/zzz0054/bio/7-5/star_out/5008135/Aligned.toTranscriptome.out.sorted.bam
# ...

# %%
## plot
# !PlotRiboDensityAroundTriAAMotifs -i {abs_path}/{out_dir_path}/RiboDensityAroundTripleteAAMotifs_D_motifDensity_dataframe.txt -o {abs_path}/{out_dir_path}/RiboDensityAroundTripleteAAMotifs_D -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 --mode mean --ymax 0.2
# Out:
# Start the step of mean value calculation...
# finishing the mean value calculation!
# Start the step of plotting...
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
## pausing score calculation
# !PausingScore  -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/PausingScore -M RPKM  -l 100 -n 10 --table 1 -S {abs_path}/selected.transcripts.info.txt -F {abs_path}/ProteinCodingSeq_cds_sequences.fa
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# There are 6600 transcripts from /home/zzz0054/bio/7-5/selected.transcripts.info.txt used for following analysis.
# The number of transcripts filtered by filter1 (len(CDS_seq)%3!=0) is : 0
# The number of transcripts filtered by filter2 (len(CDS_seq)<inCDS_lengthFilterParma) is :47
# The number of transcripts filtered by filter3 (cds_reads < inCDS_countsFilterParma(RPKM)) is : 2733
# The number of transcripts filtered by filter4 (sum(cds_reads)==0) is : 0
# The number of transcripts filtered by filter5 (annotated imcomplete) is : 0
# The number of transcripts used for pausing score calulation in /home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bamis: 3820
# The number of transcripts filtered by filter1 (len(CDS_seq)%3!=0) is : 0
# The number of transcripts filtered by filter2 (len(CDS_seq)<inCDS_lengthFilterParma) is :47
# ...

# %%
## process pausing score
# !ProcessPausingScore -i {abs_path}/{out_dir_path}/PausingScore_si-Ctrl-1_pausing_score.txt,{abs_path}/{out_dir_path}/PausingScore_si-Ctrl-2_pausing_score.txt,{abs_path}/{out_dir_path}/PausingScore_si-eIF5A-1_pausing_score.txt,{abs_path}/{out_dir_path}/PausingScore_si-eIF5A-2_pausing_score.txt -o {abs_path}/{out_dir_path}/ProcessPausingScore -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 --mode raw --ratio_filter 2 --pausing_score_filter 10
# Out:
# Start calculating the mean pausing score.
# Start calculating the position weight matrix...
# Finish the step of pwm calculation

# %%
# !RPFdist -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/RPFdist -M RPKM -S {abs_path}/selected.transcripts.info.txt -l 100 -n 10 -m 1 -e 5
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# There are 6600 transcripts from /home/zzz0054/bio/7-5/selected.transcripts.info.txt used for following analysis.
# Lenght filter(-l)---Transcripts number filtered by criterion one is : 481
# Lenght filter (3n)---Transcripts number filtered by criterion two is : 0
# Total counts filter---Transcripts number filtered by criterion three is : 687
# CDS density filter(RPKM-n or counts-n)---Transcripts number filtered by criterion four is : 885
# CDS density filter(normed-m)---Transcripts number filtered by criterion five is : 0
# Metaplots Transcript Number for bam file/home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bam is :4
# Finish the step of RPFdist calculation
# Lenght filter(-l)---Transcripts number filtered by criterion one is : 481
# Lenght filter (3n)---Transcripts number filtered by criterion two is : 0
# ...

# %%
# !GCContent -i {abs_path}/ProteinCodingSeq_transcript_sequences.fa -o {abs_path}/{out_dir_path}/GCContent --mode normal
# Out:
# Start statistic GC content...
# Finish the step of GC content!

# %%
## tAI calculation
tAI -i 2954_up_cds_sequences.fa,1598_unblocked_cds_sequences.fa,433_down_cds_sequences.fa -N tRNA_GCNs_Saccharomyces_cerevisiae.txt -o  test -u 0 -d 500 -t 2954_up,1598_unblocked,433_down

## tAI plot
tAIPlot -i <output_prefix_tAI_dataframe.txt> -o <output_prefix> -u 0 -d 500 --mode all --start 5 --window 7 --step 1
