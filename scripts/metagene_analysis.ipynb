# %%
abs_path = "/home/zzz0054/bio/7-5"
out_dir_path = "MetageneAnalysis"

# %%
# !mkdir -p {abs_path}/{out_dir_path}

# %%
# !head {abs_path}/attributes.txt
# Out:
# bamFiles	readLengths	Offsets	bamLegends
# /home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bam	27,28,29,30	11,12,13,14	si-Ctrl-1
# /home/zzz0054/bio/7-5/star_out/5008135/Aligned.toTranscriptome.out.sorted.bam	27,28,29,30	11,12,13,14	si-Ctrl-2
# /home/zzz0054/bio/7-5/star_out/5008136/Aligned.toTranscriptome.out.sorted.bam	27,28,29	11,12,13	si-eIF5A-1
# /home/zzz0054/bio/7-5/star_out/5008137/Aligned.toTranscriptome.out.sorted.bam	27,28,29	11,12,13	si-eIF5A-2

# %%
# !MetageneAnalysisForTheWholeRegions -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/MetageneAnalysisForTheWholeRegions -b 15,90,15 -l 100 -n 10 -m 1 -e 5
# Out:
# 6600  transcripts will be used in the follow analysis.
#
# Lenght filter(-l)---Transcripts number filtered by criterion one is : 481
# Lenght filter (3n)---Transcripts number filtered by criterion two is : 0
# Total counts filter---Transcripts number filtered by criterion three is : 687
# CDS density filter(RPKM-n or counts-n)---Transcripts number filtered by criterion four is : 885
# CDS density filter(normed-m)---Transcripts number filtered by criterion five is : 0
# Metaplots Transcript Number for bam file/home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bam is :4547
# Finish the step of read density calculation!
# Lenght filter(-l)---Transcripts number filtered by criterion one is : 481
# Lenght filter (3n)---Transcripts number filtered by criterion two is : 0
# Total counts filter---Transcripts number filtered by criterion three is : 776
# CDS density filter(RPKM-n or counts-n)---Transcripts number filtered by criterion four is : 813
# ...

# %%
# !PlotMetageneAnalysisForTheWholeRegions -i {abs_path}/{out_dir_path}/MetageneAnalysisForTheWholeRegions_scaled_density_dataframe.txt -o {abs_path}/{out_dir_path}/PlotMetageneAnalysisForTheWholeRegions -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 -b 15,90,15 --mode all --xlabel-loc -0.4
# Out:
# your input file is: /home/zzz0054/bio/7-5/MetageneAnalysis/MetageneAnalysisForTheWholeRegions_scaled_density_dataframe.txt
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
## metagene analysis
# !MetageneAnalysis -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/MetageneAnalysis_cds -U codon -M RPKM -u 0 -d 500 -l 100 -n 10 -m 1 -e 5 --norm yes -y 100 --CI 0.95 --type CDS
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# Lenght filter(-l)---Transcripts number filtered by criterion one is : 481
# Lenght filter (3n)---Transcripts number filtered by criterion two is : 0
# Total counts filter---Transcripts number filtered by criterion three is : 687
# CDS density filter(RPKM-n or counts-n)---Transcripts number filtered by criterion four is : 885
# CDS density filter(normed-m)---Transcripts number filtered by criterion five is : 0
# Metaplots Transcript Number for bam file/home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bam is :4547
# Finish the step of ribosomeDensityNormPerTrans
# Lenght filter(-l)---Transcripts number filtered by criterion one is : 481
# Lenght filter (3n)---Transcripts number filtered by criterion two is : 0
# Total counts filter---Transcripts number filtered by criterion three is : 776
# ...

# %%
## plot
# !PlotMetageneAnalysis -i {abs_path}/{out_dir_path}/MetageneAnalysis_cds_dataframe.txt  -o {abs_path}/{out_dir_path}/MetageneAnalysis_cds -u 0 -d 500 -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 -U codon --CI 0.95
# Out:
# your input file is: /home/zzz0054/bio/7-5/MetageneAnalysis/MetageneAnalysis_cds_dataframe.txt
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
##  metagene analysis for UTR
# !MetageneAnalysis -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/MetageneAnalysis_utr -U nt -M RPKM -u 50 -d 50 -l 50 -n 10 -m 1 -e 5 --norm yes -y 100 --CI 0.95 --type UTR
## plot
# !PlotMetageneAnalysis -i <output_prefix_UTR_dataframe.txt>  -o -i {abs_path}/{out_dir_path}/MetageneAnalysis_cds_dataframe.txt  -o {abs_path}/{out_dir_path}/MetageneAnalysis_utr -u 50 -d 50 -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2 -U nt --CI 0.95
# Out:
# Notice! The -y parameter should not be bigger than -l parameter!
# Traceback (most recent call last):
#   File "/home/zzz0054/miniconda3/envs/ribo4/bin/MetageneAnalysis", line 8, in <module>
#     sys.exit(main())
#   File "/home/zzz0054/miniconda3/envs/ribo4/lib/python3.8/site-packages/RiboMiner/MetageneAnalysis.py", line 453, in main
#     parse_args_for_CDS_metagene_analysis()
#   File "/home/zzz0054/miniconda3/envs/ribo4/lib/python3.8/site-packages/RiboMiner/MetageneAnalysis.py", line 385, in parse_args_for_CDS_metagene_analysis
#     raise IOError("Output codon density num bigger than the selective region length [-y > -u or -y > -d]. Reset -y or -u and -d  parameters.")
# OSError: Output codon density num bigger than the selective region length [-y > -u or -y > -d]. Reset -y or -u and -d  parameters.
# /bin/bash: line 1: output_prefix_UTR_dataframe.txt: No such file or directory

# %%
## polarity calculation
# !PolarityCalculation -f {abs_path}/attributes.txt -c {abs_path}/longest.transcripts.info.txt -o {abs_path}/{out_dir_path}/PolarityCalculation -n 64
# Out:
# your input : 4 bam files
# 6600  transcripts will be used in the follow analysis.
#
# There are 6600 transcripts with both start and stop codon will be used for following analysis.
# Metaplots Transcript Number for bam file/home/zzz0054/bio/7-5/star_out/5008134/Aligned.toTranscriptome.out.sorted.bam is :4785
# The number of genes filtered by read counts equals to 64 is: 1815
# There are 4785 genes used for plot polarity value
# Metaplots Transcript Number for bam file/home/zzz0054/bio/7-5/star_out/5008135/Aligned.toTranscriptome.out.sorted.bam is :4385
# The number of genes filtered by read counts equals to 64 is: 2215
# There are 4385 genes used for plot polarity value
# Metaplots Transcript Number for bam file/home/zzz0054/bio/7-5/star_out/5008136/Aligned.toTranscriptome.out.sorted.bam is :4726
# The number of genes filtered by read counts equals to 64 is: 1874
# There are 4726 genes used for plot polarity value
# ...

# %%
## plot
# !PlotPolarity -i {abs_path}/{out_dir_path}/PolarityCalculation_polarity_dataframe.txt -o {abs_path}/{out_dir_path}/PlotPolarity -g si-Ctrl,si-eIF5A -r si-Ctrl-1,si-Ctrl-2__si-eIF5A-1,si-eIF5A-2  -y 5
# Out:
# Start plot the polarity...
# /home/zzz0054/miniconda3/envs/ribo4/lib/python3.8/site-packages/RiboMiner/PlotPolarity.py:50: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(lst,hist=False,rug=False,label=samples[i],color=colors[i])
# /home/zzz0054/miniconda3/envs/ribo4/lib/python3.8/site-packages/RiboMiner/PlotPolarity.py:50: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# ...
