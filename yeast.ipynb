# %%
# !wget https://ftp.ensembl.org/pub/release-61/fasta/saccharomyces_cerevisiae/dna/Saccharomyces_cerevisiae.EF2.61.dna.toplevel.fa.gz
# Out:
# --2024-06-23 10:38:05--  https://ftp.ensembl.org/pub/release-61/fasta/saccharomyces_cerevisiae/dna/Saccharomyces_cerevisiae.EF2.61.dna.toplevel.fa.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3647429 (3.5M) [application/x-gzip]
# Saving to: ‘Saccharomyces_cerevisiae.EF2.61.dna.toplevel.fa.gz’
#
# Saccharomyces_cerev 100%[===================>]   3.48M   614KB/s    in 6.0s
#
# 2024-06-23 10:38:12 (598 KB/s) - ‘Saccharomyces_cerevisiae.EF2.61.dna.toplevel.fa.gz’ saved [3647429/3647429]

# %%
# !wget https://ftp.ensembl.org/pub/release-61/gtf/saccharomyces_cerevisiae/Saccharomyces_cerevisiae.EF2.61.gtf.gz
# Out:
# --2024-06-23 10:39:01--  https://ftp.ensembl.org/pub/release-61/gtf/saccharomyces_cerevisiae/Saccharomyces_cerevisiae.EF2.61.gtf.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 376626 (368K) [application/x-gzip]
# Saving to: ‘Saccharomyces_cerevisiae.EF2.61.gtf.gz’
#
# Saccharomyces_cerev 100%[===================>] 367.80K   508KB/s    in 0.7s
#
# 2024-06-23 10:39:02 (508 KB/s) - ‘Saccharomyces_cerevisiae.EF2.61.gtf.gz’ saved [376626/376626]

# %%
# !gunzip ../*.gz

# %%
# !prepare_transcripts -g /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae_old/Saccharomyces_cerevisiae.R64-1-1.112.gtf -f /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/rna_coding_R64-1-1_20110203.fasta -o /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/annot
# Out:
# [2024-06-23 11:10:09] Preparing annotation files ...
# 	Reading the GTF file: /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae_old/Saccharomyces_cerevisiae.R64-1-1.112.gtf .......
# 	Process the transcripts ....
# Traceback (most recent call last):
#   File "/home/zzz0054/.local/bin/prepare_transcripts", line 8, in <module>
#     sys.exit(main())
#   File "/home/zzz0054/.local/lib/python3.8/site-packages/RiboCode/prepare_transcripts.py", line 388, in main
#     processTranscripts(args.genomeFasta,args.gtfFile,args.out_dir)
#   File "/home/zzz0054/.local/lib/python3.8/site-packages/RiboCode/prepare_transcripts.py", line 364, in processTranscripts
#     transcript_seq = [genomic_seq.get_seq(tobj.chrom,exon_iv.start,exon_iv.end,exon_iv.strand) for exon_iv in tobj.genomic_exons]
#   File "/home/zzz0054/.local/lib/python3.8/site-packages/RiboCode/prepare_transcripts.py", line 364, in <listcomp>
# ...

# %%
# !OutputTranscriptInfo -c /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/annot/transcripts_cds.txt -g /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/Saccharomyces_cerevisiae.R64-1-1.112.gtf -f /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/annot/transcripts_sequence.fa -o /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/longest.transcripts.info.txt -O /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/all.transcripts.info.txt
