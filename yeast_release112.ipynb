# %%
# !wget https://ftp.ensembl.org/pub/release-112/gtf/saccharomyces_cerevisiae/Saccharomyces_cerevisiae.R64-1-1.112.gtf.gz
# Out:
# --2024-06-13 21:27:17--  https://ftp.ensembl.org/pub/release-112/gtf/saccharomyces_cerevisiae/Saccharomyces_cerevisiae.R64-1-1.112.gtf.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 595453 (581K) [application/x-gzip]
# Saving to: ‘Saccharomyces_cerevisiae.R64-1-1.112.gtf.gz’
#
# Saccharomyces_cerev 100%[===================>] 581.50K   542KB/s    in 1.1s
#
# 2024-06-13 21:27:18 (542 KB/s) - ‘Saccharomyces_cerevisiae.R64-1-1.112.gtf.gz’ saved [595453/595453]

# %%
# !wget https://ftp.ensembl.org/pub/release-61/gtf/saccharomyces_cerevisiae/Saccharomyces_cerevisiae.EF2.61.gtf.gz
# Out:
# --2024-06-23 10:21:43--  https://ftp.ensembl.org/pub/release-61/gtf/saccharomyces_cerevisiae/Saccharomyces_cerevisiae.EF2.61.gtf.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 376626 (368K) [application/x-gzip]
# Saving to: ‘Saccharomyces_cerevisiae.EF2.61.gtf.gz’
#
# Saccharomyces_cerev 100%[===================>] 367.80K   510KB/s    in 0.7s
#
# 2024-06-23 10:21:45 (510 KB/s) - ‘Saccharomyces_cerevisiae.EF2.61.gtf.gz’ saved [376626/376626]

# %%
# !wget https://ftp.ensembl.org/pub/release-112/fasta/saccharomyces_cerevisiae/dna/Saccharomyces_cerevisiae.R64-1-1.dna_sm.toplevel.fa.gz
# Out:
# --2024-06-13 21:28:40--  https://ftp.ensembl.org/pub/release-112/fasta/saccharomyces_cerevisiae/dna/Saccharomyces_cerevisiae.R64-1-1.dna_sm.toplevel.fa.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3871027 (3.7M) [application/x-gzip]
# Saving to: ‘Saccharomyces_cerevisiae.R64-1-1.dna_sm.toplevel.fa.gz’
#
# Saccharomyces_cerev 100%[===================>]   3.69M  2.86MB/s    in 1.3s
#
# 2024-06-13 21:28:41 (2.86 MB/s) - ‘Saccharomyces_cerevisiae.R64-1-1.dna_sm.toplevel.fa.gz’ saved [3871027/3871027]

# %%
# !gunzip *.gz

# %%
# !prepare_transcripts -g /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/Saccharomyces_cerevisiae.R64-1-1.112.gtf -f /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/rna_coding_R64-1-1_20110203.fasta -o ./annot
# Out:
# [2024-06-19 21:47:09] Preparing annotation files ...
# 	Loading transcripts.pickle ...
# [2024-06-19 21:47:09] The step of preparing transcript annotation has been completed.

# %%
# !OutputTranscriptInfo -c ./annot/transcripts_cds.txt -g ./Saccharomyces_cerevisiae.R64-1-1.112.gtf -f ./annot/transcripts_sequence.fa -o longest.transcripts.info.txt -O ./all.transcripts.info.txt
# Out:
# Starting outputing longest trans...
# 6600  transcripts will be used in the follow analysis.
#
# Finishing!
# Starting outputing all trans...
# Finishing!

# %%
# !GetProteinCodingSequence -i ./annot/transcripts_sequence.fa  -c ./longest.transcripts.info.txt -o output_prefix --mode whole
# Out:
# 6600  transcripts will be used in the follow analysis.
#
# Notes: There are 0 transcripts whose cds sequence cannot be divided by 3!
# Finish the step of extracting sequences!

# %%
# !GetUTRSequences -i ./annot/transcripts_sequence.fa -o output_prefix -c ./annot/transcripts_cds.txt
# Out:
# Start extracting UTR sequences...
# Notes: There are 0 transcripts whose cds sequence cannot be divided by 3!
# Notes: There are 0 transcripts with 5UTR length equaling 0 which will be filtered in 5UTR sequence!
# Notes: There are 6600 transcripts with 3UTR length equaling 0 which will be filtered in 3UTR sequence!
# Notes: There are 0 transcripts with CDS length equaling 0 which will be filtered in CDS sequence!
# Finish the step of UTR sequences extracting!

# %% [markdown]
# bam download https://www.ncbi.nlm.nih.gov/sra

# %%
# !wget https://trace.ncbi.nlm.nih.gov/Traces/sra-reads-be/fastq?acc=SRR5008134
# Out:
# --2024-06-13 21:38:41--  https://trace.ncbi.nlm.nih.gov/Traces/sra-reads-be/fastq?acc=SRR5008134
# Resolving trace.ncbi.nlm.nih.gov (trace.ncbi.nlm.nih.gov)... 130.14.29.113, 2607:f220:41e:4290::113
# Connecting to trace.ncbi.nlm.nih.gov (trace.ncbi.nlm.nih.gov)|130.14.29.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘fastq?acc=SRR5008134’
#
# fastq?acc=SRR500813     [              <=>   ]   1.24G  1.32MB/s    in 16m 7s
#
# 2024-06-13 21:54:49 (1.31 MB/s) - ‘fastq?acc=SRR5008134’ saved [1332708185]

# %% [markdown]
# metaplots -a <RiboCode_annot> -r <transcript.bam> -o <output_prefix>

# %%
# !metaplots -a /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/annot -r /home/zzz0054/bio/dataset/Saccharomyces_cerevisiae/SRR5008134_hisat2_sorted.bam -o SRR5008134
# Out:
# [2024-06-19 21:47:49] Create metaplot file and predict the P-site locations ...
# 	Loading transcripts.pickle ...
# Error, the references in bam are different from transcriptome annotation,
# you should input the transcriptome BAM file.
