# %%
# !conda create -n ribominer python=3.7

# %%
# !conda activate ribominer

# %%
# install pyfasta from pyfasta_py3
# !git clone https://github.com/msqiqi10/pyfasta_py3
# !pip3 install -e pyfasta_py3

# %%
# !conda install -c bioconda ribominer
